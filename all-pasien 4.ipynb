# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import loadmat

import time

import librosa

from tqdm import tqdm_notebook
import torch

from matplotlib.gridspec import GridSpec
import seaborn as sns
from torch.utils.data import DataLoader
import torchvision


from utils import plot_spk_rec, plot_mem_rec
from models import SNN, SpikingConvLayer, ReadoutLayer, SurrogateHeaviside, SpikingDenseLayer

from optim import RAdam

# %%
X_train_batch = torch.Tensor(168, 72, 33, 155)
yy_train_batch = np.zeros((168,))

# %%
#label 1 for the ictal segment

for i in range(16):
    yy_train_batch[i] = 1

# %%
Y_train_batch=torch.from_numpy(yy_train_batch)

# %%
for i in range (16):    
    data = loadmat('dataset/seizure-detection-upenn/clips/Volumes/Seagate/seizure_detection/competition_data/clips/Patient_4/Patient_4_ictal_segment_%s.mat' %(i+1))
    #Pdata=data['ictal_segment_%s' %(i+1)]
    PPdata=data['data']
    Matrix=PPdata[0,0] 
    f, t, Sxx = signal.spectrogram(PPdata[:,:], fs=400,noverlap=32,scaling='spectrum',nperseg=64)
    X_train_batch[i,:]=torch.from_numpy(Sxx)
    
for i in range (152):   
    data = loadmat('dataset/seizure-detection-upenn/clips/Volumes/Seagate/seizure_detection/competition_data/clips/Patient_4/Patient_4_interictal_segment_%s.mat' %(i+1))
    #Pdata=data['interictal_segment_%s' %(i+1)]
    PPdata=data['data']
    Matrix=PPdata[0,0] 
    f, t, Sxx = signal.spectrogram(PPdata[:,:], fs=400,noverlap=32,scaling='spectrum',nperseg=64)
    X_train_batch[(i+16),:]=torch.from_numpy(Sxx)

# %%
X_train_batch.shape
# Out:
# torch.Size([168, 72, 33, 155])

# %%
X_Valid_batch = torch.Tensor(21, 72, 33, 155)
yy_Valid_batch = np.zeros((21,))

# %%
#label 1 for the ictal segment

for i in range(2):
    yy_Valid_batch[i] = 1

# %%
Y_Valid_batch=torch.from_numpy(yy_Valid_batch)

# %%
# Data for training and testing the network are available at https://msel.mayo.edu/data.html under "Sz detection data clips" for Patient_3. 

for i in range (2):    
    data = loadmat('dataset/seizure-detection-upenn/clips/Volumes/Seagate/seizure_detection/competition_data/clips/Patient_4/Patient_4_ictal_segment_%s.mat' %(i+17))
    #Pdata=data['ictal_segment_%s' %(i+21)]
    PPdata=data['data']
    Matrix=PPdata[0,0] 
    f, t, Sxx = signal.spectrogram(PPdata[:,:], fs=400,noverlap=32,scaling='spectrum',nperseg=64)
    X_Valid_batch[i,:]=torch.from_numpy(Sxx)
    
for i in range (19):   
    data = loadmat('dataset/seizure-detection-upenn/clips/Volumes/Seagate/seizure_detection/competition_data/clips/Patient_4/Patient_4_interictal_segment_%s.mat' %(i+153))
    #Pdata=data['interictal_segment_%s' %(i+51)]
    PPdata=data['data']
    Matrix=PPdata[0,0] 
    f, t, Sxx = signal.spectrogram(PPdata[:,:], fs=400,noverlap=32,scaling='spectrum',nperseg=64)
    X_Valid_batch[(i+2),:]=torch.from_numpy(Sxx)

# %%
X_Valid_batch.shape
# Out:
# torch.Size([21, 72, 33, 155])

# %%
X_Test_batch = torch.Tensor(21, 72, 33, 155)
yy_Test_batch = np.zeros((21,))

# %%
#label 1 for the ictal segment

for i in range(2):
    yy_Test_batch[i] = 1

# %%
Y_Test_batch=torch.from_numpy(yy_Test_batch)

# %%
# Data for training and testing the network are available at https://msel.mayo.edu/data.html under "Sz detection data clips" for Patient_3. 

for i in range (2):    
    data = loadmat('dataset/seizure-detection-upenn/clips/Volumes/Seagate/seizure_detection/competition_data/clips/Patient_4/Patient_4_ictal_segment_%s.mat' %(i+19))
    #Pdata=data['ictal_segment_%s' %(i+301)]
    PPdata=data['data']
    Matrix=PPdata[0,0] 
    f, t, Sxx = signal.spectrogram(PPdata[:,:], fs=400,noverlap=32,scaling='spectrum',nperseg=64)
    X_Test_batch[i,:]=torch.from_numpy(Sxx)
    
for i in range (19):   
    data = loadmat('dataset/seizure-detection-upenn/clips/Volumes/Seagate/seizure_detection/competition_data/clips/Patient_4/Patient_4_interictal_segment_%s.mat' %(i+172))
    #Pdata=data['interictal_segment_%s' %(i+701)]
    PPdata=data['data']
    Matrix=PPdata[0,0] 
    f, t, Sxx = signal.spectrogram(PPdata[:,:], fs=400,noverlap=32,scaling='spectrum',nperseg=64)
    X_Test_batch[(i+2),:]=torch.from_numpy(Sxx)

# %%
X_Test_batch.shape
# Out:
# torch.Size([21, 72, 33, 155])

# %%
dtype = torch.float
device = torch.device("cuda:0")

# %%
spike_fn = SurrogateHeaviside.apply

w_init_std = 0.15


layers = []

in_channels = 72
out_channels = 32
kernel_size = (4,3)
dilation = (1,1)
nb_inputs = 155
nb_outputs = nb_inputs # padding mode is "same"
layers.append(SpikingConvLayer(nb_inputs, nb_outputs,
                 in_channels, out_channels, kernel_size, dilation,
                 spike_fn, w_init_mean=0., w_init_std=w_init_std))


in_channels = out_channels
out_channels = 32
kernel_size = (4,3)
dilation = (4,3)
nb_inputs = nb_outputs
nb_outputs = nb_inputs # padding mode is "same"
layers.append(SpikingConvLayer(nb_inputs, nb_outputs,
                 in_channels, out_channels, kernel_size, dilation,
                 spike_fn, w_init_mean=0., w_init_std=w_init_std))

in_channels = out_channels
out_channels = 32
kernel_size = (4,3)
dilation = (16,9)
nb_inputs = nb_outputs
nb_outputs = nb_inputs # padding mode is "same"
layers.append(SpikingConvLayer(nb_inputs, nb_outputs,
                 in_channels, out_channels, kernel_size, dilation,
                 spike_fn, w_init_mean=0., w_init_std=w_init_std, flatten_output=True))

# previous layer output has been flattened
nb_inputs = nb_outputs*out_channels
nb_outputs = 2 
time_reduction="mean" #mean or max
layers.append(ReadoutLayer(nb_inputs, nb_outputs,
                 w_init_mean=0., w_init_std=w_init_std, time_reduction=time_reduction))

snn = SNN(layers).to(device, dtype)

#X_batch, _ = next(iter(train_dataloader))

X_train_batch = X_train_batch.to(device, dtype)
snn(X_train_batch)

for i,l in enumerate(snn.layers):
    if isinstance(l, SpikingDenseLayer) or isinstance(l, SpikingConvLayer):
        print("Layer {}: average number of spikes={:.4f}".format(i,l.spk_rec_hist.mean()))
# Out:
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1738
# Layer 2: average number of spikes=0.1492

# %%
nb_plt = 9
batch_size = 70

batch_idx = np.random.choice(batch_size, nb_plt, replace=False)

# Plotting spike trains or membrane potential
for i,l in enumerate(snn.layers):
    
    if isinstance(l, SpikingDenseLayer):
        spk_rec = l.spk_rec_hist
        plot_spk_rec(spk_rec, idx=batch_idx)
    elif isinstance(l, SpikingConvLayer):
        spk_rec = l.spk_rec_hist
        plot_spk_rec(spk_rec.sum(1), idx=batch_idx)
    else:
        mem_rec = l.mem_rec_hist
        plot_mem_rec(mem_rec, batch_idx)

# %%
Y_train_batch = torch.tensor(Y_train_batch, dtype=torch.long, device=device)   
Y_Test_batch = torch.tensor(Y_Test_batch, dtype=torch.long, device=device)
# Out:
# /tmp/ipykernel_3776954/440090667.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Y_train_batch = torch.tensor(Y_train_batch, dtype=torch.long, device=device)
# /tmp/ipykernel_3776954/440090667.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Y_Test_batch = torch.tensor(Y_Test_batch, dtype=torch.long, device=device)

# %%
def train(model, params, optimizer, reg_loss_coef, nb_epochs, scheduler=None, warmup_epochs=0):
    
    log_softmax_fn = torch.nn.LogSoftmax(dim=1)
    loss_fn = torch.nn.NLLLoss()
    
    if warmup_epochs > 0:
        for g in optimizer.param_groups:
            g['lr'] /= len(X_train_batch)*warmup_epochs
        warmup_itr = 1
    
    hist = {'loss':[], 'valid_accuracy':[]}
    for e in range(nb_epochs):
        local_loss = []
        reg_loss = [[] for _ in range(len(model.layers)-1)]
        

           
        x_batch = X_train_batch.cuda()
        y_batch = Y_train_batch.cuda()
                
        output, loss_seq = model(x_batch)
        log_p_y = log_softmax_fn(output)
        loss_val = loss_fn(log_p_y, y_batch)
        local_loss.append(loss_val.item())
                
        for i,loss in enumerate(loss_seq[:-1]):
            reg_loss_val = reg_loss_coef*loss*(i+1)/len(loss_seq[:-1])
            loss_val += reg_loss_val
            reg_loss[i].append(reg_loss_val.item())
                    

        optimizer.zero_grad()
        loss_val.backward()
        torch.nn.utils.clip_grad_value_(model.parameters(), 5)
        optimizer.step()
        model.clamp()
                
        if e < warmup_epochs:
            for g in optimizer.param_groups:
                g['lr'] *= (warmup_itr+1)/(warmup_itr)
            warmup_itr += 1
                
        
                
        if scheduler is not None and e >= warmup_epochs:
            scheduler.step()
        
        mean_loss = np.mean(local_loss)
        hist['loss'].append(mean_loss)
        print("Epoch %i: loss=%.5f"%(e+1,mean_loss))
        
        for i,loss in enumerate(reg_loss):
            mean_reg_loss = np.mean(loss)
            print("Layer %i: reg loss=%.5f"%(i,mean_reg_loss))
            
        for i,l in enumerate(snn.layers[:-1]):
            print("Layer {}: average number of spikes={:.4f}".format(i,l.spk_rec_hist.mean()))
        
        valid_accuracy = compute_classification_accuracy(model)
        hist['valid_accuracy'].append(valid_accuracy)
        print("Validation accuracy=%.3f"%(valid_accuracy))
        
    return hist
        
def compute_classification_accuracy(model):
    accs = []
    
    with torch.no_grad():
          
        x_batch = X_Valid_batch.cuda()
        y_batch = Y_Valid_batch.cuda()
        output, _ = model(x_batch)
        _,am=torch.max(output,1) # argmax over output units
        tmp = np.mean((y_batch==am).detach().cpu().numpy()) # compare to labels
        accs.append(tmp)
       
    return np.mean(accs)

# %%
lr = 1e-3
weight_decay = 1e-5
reg_loss_coef = 0.1
nb_epochs = 20

params = [{'params':l.w, 'lr':lr, "weight_decay":weight_decay } for i,l in enumerate(snn.layers)]
params += [{'params':l.b, 'lr':lr} for i,l in enumerate(snn.layers)]
if snn.layers[-1].time_reduction == "mean":
    params += [{'params':l.beta, 'lr':lr} for i,l in enumerate(snn.layers[:-1])]
elif snn.layers[-1].time_reduction == "max":
    params += [{'params':l.beta, 'lr':lr} for i,l in enumerate(snn.layers)]
else:
    raise ValueError("Readout time recution should be 'max' or 'mean'")
    
optimizer = RAdam(params)
 
gamma = 0.85
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma, last_epoch=-1)

hist = train(snn, params, optimizer, reg_loss_coef, nb_epochs=nb_epochs,
                  scheduler=scheduler, warmup_epochs=1)
# Out:
# /data/valencia/optim.py:45: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1005.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# Epoch 1: loss=1.04644
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00746
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1738
# Layer 2: average number of spikes=0.1492
# Validation accuracy=0.810
# Epoch 2: loss=0.44946
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00745
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1738
# Layer 2: average number of spikes=0.1490
# Validation accuracy=0.905
# Epoch 3: loss=0.36194
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00744
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1738
# Layer 2: average number of spikes=0.1489
# Validation accuracy=0.905
# Epoch 4: loss=0.44514
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00744
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1738
# Layer 2: average number of spikes=0.1488
# Validation accuracy=0.905
# Epoch 5: loss=0.48842
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00743
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1737
# Layer 2: average number of spikes=0.1487
# Validation accuracy=0.905
# Epoch 6: loss=0.50776
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00743
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1737
# Layer 2: average number of spikes=0.1486
# Validation accuracy=0.905
# Epoch 7: loss=0.50487
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00743
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1737
# Layer 2: average number of spikes=0.1486
# Validation accuracy=0.905
# Epoch 8: loss=0.50316
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00743
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1737
# Layer 2: average number of spikes=0.1486
# Validation accuracy=0.905
# Epoch 9: loss=0.50223
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00743
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1737
# Layer 2: average number of spikes=0.1485
# Validation accuracy=0.905
# Epoch 10: loss=0.50218
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00743
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1737
# Layer 2: average number of spikes=0.1485
# Validation accuracy=0.905
# Epoch 11: loss=0.50192
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00742
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1736
# Layer 2: average number of spikes=0.1485
# Validation accuracy=0.905
# Epoch 12: loss=0.50389
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00742
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1736
# Layer 2: average number of spikes=0.1484
# Validation accuracy=0.905
# Epoch 13: loss=0.50422
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00742
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1736
# Layer 2: average number of spikes=0.1484
# Validation accuracy=0.905
# Epoch 14: loss=0.50278
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00742
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1736
# Layer 2: average number of spikes=0.1484
# Validation accuracy=0.905
# Epoch 15: loss=0.49950
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00742
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1736
# Layer 2: average number of spikes=0.1484
# Validation accuracy=0.905
# Epoch 16: loss=0.49848
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00742
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1736
# Layer 2: average number of spikes=0.1483
# Validation accuracy=0.905
# Epoch 17: loss=0.49860
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00742
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1736
# Layer 2: average number of spikes=0.1483
# Validation accuracy=0.905
# Epoch 18: loss=0.49710
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00579
# Layer 2: reg loss=0.00742
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1736
# Layer 2: average number of spikes=0.1483
# Validation accuracy=0.905
# Epoch 19: loss=0.49491
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00578
# Layer 2: reg loss=0.00741
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1735
# Layer 2: average number of spikes=0.1483
# Validation accuracy=0.905
# Epoch 20: loss=0.49470
# Layer 0: reg loss=0.00483
# Layer 1: reg loss=0.00578
# Layer 2: reg loss=0.00741
# Layer 0: average number of spikes=0.2897
# Layer 1: average number of spikes=0.1735
# Layer 2: average number of spikes=0.1483
# Validation accuracy=0.905

# %%
def compute_test_accuracy(model):
    accs = []
    
    with torch.no_grad():
          
        x_batch = X_Test_batch.cuda()
        y_batch = Y_Test_batch.cuda()
        output, _ = model(x_batch)
        _,am=torch.max(output,1) # argmax over output units
        tmp = np.mean((y_batch==am).detach().cpu().numpy()) # compare to labels
        accs.append(tmp)
       
    return np.mean(accs)

test_accuracy = compute_test_accuracy(snn)
print("Test accuracy=%.3f"%(test_accuracy))
# Out:
# Test accuracy=0.905

# %%
x_batch = X_Test_batch.cuda()
y_batch = Y_Test_batch.cuda()
output, _ = snn(x_batch)
_,am=torch.max(output,1) # argmax over output units
Targets=y_batch.cpu().numpy()
Predictions=am.cpu().numpy()

# %%
from sklearn.metrics import confusion_matrix 
import itertools

# %%
cm = confusion_matrix(Targets, Predictions)

# %%
def plot_confusion_matrix(cm, classes,
                         normalize=False,
                         title='Confusion matrix',
                         cmap=plt.cm.Blues):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
        
    print(cm)
    
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                horizontalalignment='center',
                color='white' if cm[i, j] > thresh else "black")
        
    plt.tight_layout()
    plt.ylabel('Actual Diagnosis')
    plt.xlabel('SNN Prediction')

# %%
cm_plot_labels = ['Seizure-free', 'Seizure']
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[19  0]
#  [ 2  0]]

# %%
from sklearn.metrics import classification_report
print (classification_report(y_batch.cpu().numpy(), am.cpu().numpy()))
#print (classification_report(y_batch, am))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        19
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.90        21
#    macro avg       0.45      0.50      0.48        21
# weighted avg       0.82      0.90      0.86        21
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
